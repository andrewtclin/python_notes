# %%
# Twitter Bot with Twitter API
# Tweepy API - Python library to access twitter API

import tweepy
import time

# We need to first authenticated it
# This is to verify our account so that you can use it --> API needs to know who
auth = tweepy.OAuth1UserHandler(consumer_key, consumer_secret, access_token, access_token_secret)

api = tweepy.API(auth) # After authentication, we have access to the API

# public_tweets = api.home_timeline()
# for tweet in public_tweets:
#     print(tweet.text)

# user = api.me()
# user --> Information about myself --> user.name, user.screen_name, user.followers_count

# ---------------- #

# Create a bot -> someone follows you, you follow back
'''
def limit_handler(cursor):
    try:
        while True:
            yield cursor.next()
    except tweepy.RateLimitError:
        time.sleep(1000) # 1000 milliseconds / 1s

for followers in limit_handler(tweepy.Cursor(api.followers).items()): 
    # Cursor allows tweepy to go through entire info on twitter
    if follower.name == 'follower_A': # follower.followers_count > 100
        follower.follow()
        break
    
'''

# Create a bot -> loves the tweet depending on a certain words
'''
def limit_handler(cursor):
    try:
        while True:
            yield cursor.next()
    except tweepy.RateLimitError:
        time.sleep(1000) # 1000 milliseconds / 1s

search_string = 'python'
num_tweets = 2

for tweet in tweepy.Cursor(api.search, search_string).items(num_tweets):
    try:
        tweet.favorite()
    except tweepy.TweepyError as err:
        print(err.reason)
    except stopIteration:
        break
'''
